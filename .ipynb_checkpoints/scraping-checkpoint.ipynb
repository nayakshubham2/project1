# %%
import datetime
import json
import base64
import requests
from bs4 import BeautifulSoup
from dateutil.parser import parse as parse_dt
import google.generativeai as genai
import os

DISCOURSE_URL = "https://discourse.onlinedegree.iitm.ac.in"
TDS_CATEGORY = 34

DISCOURSE_TOKEN = "P2XJaNYaHonbGBgsNoLucL9q4mnq8dS%2FMkL56R4rycd%2F7n7X9hG7e6pmk%2FefK4RabuM90gPZyrQ8UenZ44gAQvgYKb%2FF8d8lIIl4BQ1MYD%2BMFsRUNQow25BJ5Rf8ZUAy2XXOQNguGKylg4%2BfUjiZUUbBInHsrdiP%2F0ih9nYZayak%2BE0JX05%2FB8537cCClZbob4dpcuqz3j3LiVV1MTwR8vzWIfzO%2FM8MJmmnWYi6x5ZgNyRUv1G2Mg%2FZw2kTFlFVynDGv7rah7v1ivRSTnUKObEQH0Bq0ZF5s5hw4XuCRxdQMgNWABf%2FvIpEJ9YE%2FMdRcfl3vQ%3D%3D--owOelRXfxmm2t8sY--pHx15knb6VqdnTj0974gvg%3D%3D"

session = requests.Session()
session.cookies.set('_t', DISCOURSE_TOKEN, domain="discourse.onlinedegree.iitm.ac.in")
# Out:
# Cookie(version=0, name='_t', value='P2XJaNYaHonbGBgsNoLucL9q4mnq8dS%2FMkL56R4rycd%2F7n7X9hG7e6pmk%2FefK4RabuM90gPZyrQ8UenZ44gAQvgYKb%2FF8d8lIIl4BQ1MYD%2BMFsRUNQow25BJ5Rf8ZUAy2XXOQNguGKylg4%2BfUjiZUUbBInHsrdiP%2F0ih9nYZayak%2BE0JX05%2FB8537cCClZbob4dpcuqz3j3LiVV1MTwR8vzWIfzO%2FM8MJmmnWYi6x5ZgNyRUv1G2Mg%2FZw2kTFlFVynDGv7rah7v1ivRSTnUKObEQH0Bq0ZF5s5hw4XuCRxdQMgNWABf%2FvIpEJ9YE%2FMdRcfl3vQ%3D%3D--owOelRXfxmm2t8sY--pHx15knb6VqdnTj0974gvg%3D%3D', port=None, port_specified=False, domain='discourse.onlinedegree.iitm.ac.in', domain_specified=True, domain_initial_dot=False, path='/', path_specified=True, secure=False, expires=None, discard=True, comment=None, comment_url=None, rest={'HttpOnly': None}, rfc2109=False)

# %%
resp = session.get(f"{DISCOURSE_URL}/c/courses/tds-kb/{TDS_CATEGORY}.json?page=0")
js = resp.json()
print(js['topic_list']['topics'][0]) #check if it worked
# Out:
# {'id': 176077, 'title': 'Project1 - Virtual TA - Discussion Thread [TDS May 2025]', 'fancy_title': 'Project1 - Virtual TA - Discussion Thread [TDS May 2025]', 'slug': 'project1-virtual-ta-discussion-thread-tds-may-2025', 'posts_count': 302, 'reply_count': 199, 'highest_post_number': 311, 'image_url': None, 'created_at': '2025-05-22T21:36:32.840Z', 'last_posted_at': '2025-06-13T11:31:46.268Z', 'bumped': True, 'bumped_at': '2025-06-13T11:31:46.268Z', 'archetype': 'regular', 'unseen': False, 'last_read_post_number': 87, 'unread': 0, 'new_posts': 0, 'unread_posts': 0, 'pinned': True, 'unpinned': None, 'excerpt': 'Please post any questions related to Project 1 \nPlease use markdown code formatting (fenced code blocks beginning with ```) when sharing code (rather than screenshots). It’s easier for us to copy-paste and test. \nDeadlin&hellip;', 'visible': True, 'closed': False, 'archived': False, 'notification_level': 1, 'bookmarked': False, 'liked': False, 'tags': ['term2-2025', 'tds-project-1'], 'tags_descriptions': {}, 'views': 2120, 'like_count': 110, 'has_summary': True, 'last_poster_username': 'ayushpatel', 'category_id': 34, 'pinned_globally': False, 'featured_link': None, 'has_accepted_answer': False, 'can_vote': False, 'posters': [{'extras': None, 'description': 'Original Poster', 'user_id': 15651, 'primary_group_id': 294, 'flair_group_id': 294}, {'extras': None, 'description': 'Frequent Poster', 'user_id': 16094, 'primary_group_id': 294, 'flair_group_id': 294}, {'extras': None, 'description': 'Frequent Poster', 'user_id': 31631, 'primary_group_id': 294, 'flair_group_id': 294}, {'extras': None, 'description': 'Frequent Poster', 'user_id': 17206, 'primary_group_id': 294, 'flair_group_id': 294}, {'extras': 'latest', 'description': 'Most Recent Poster', 'user_id': 19273, 'primary_group_id': 294, 'flair_group_id': 294}]}

# %%
def parse_dt(dtstr):
    return datetime.datetime.fromisoformat(dtstr.replace("Z", "+00:00"))

START_DATE = datetime.datetime(2025, 1, 1, tzinfo=datetime.timezone.utc)
all_topics = []

for page in range(0, 11):  # pages 0 to 10 inclusive
    url = f"{DISCOURSE_URL}/c/courses/tds-kb/{TDS_CATEGORY}.json?page={page}"
    r = session.get(url)
    data = r.json()
    topics = data.get("topic_list", {}).get("topics", [])
    for t in topics:
        last_posted_at = parse_dt(t["last_posted_at"]) if t.get("last_posted_at") else None
        if last_posted_at and last_posted_at > START_DATE:
            topic_info = {
                "id": t["id"],
                "title": t["title"],
                "slug": t["slug"],
                "created_at": t.get("created_at"),
                "last_posted_at": t.get("last_posted_at"),
                "posts_count": t.get("posts_count"),
                "reply_count": t.get("reply_count"),
                "views": t.get("views"),
                "tags": t.get("tags", []),
                "category_id": t.get("category_id"),
                "last_poster_username": t.get("last_poster_username"),
                "excerpt": t.get("excerpt"),
                "url": f"{DISCOURSE_URL}/t/{t['slug']}/{t['id']}"
            }
            all_topics.append(topic_info)

print(f"Collected {len(all_topics)} topics after {START_DATE.date()}")

# Save to file if needed
import json
with open("tds_topics.json", "w") as f:
    json.dump(all_topics, f, indent=2)
# Out:
# Collected 189 topics after 2025-01-01

# %% [markdown]
# ## Start Scraping all posts

# %% [markdown]
# ### Image to Description Function

# %%
with open("tds_topics.json", "r") as f:
    all_topics = json.load(f)

# %%
# gemini_api_key = os.environ.get('GOOGLE_API_KEY')
gemini_api_key = 'AIzaSyDPDhdp-ECcGsnneoIkX0cBnfZxHU5-zzk'
genai.configure(api_key=gemini_api_key)

# %%
def get_image_description(image_bytes: bytes) -> str:
    """Generates a description for an image using the Gemini API."""
    try:
        model = genai.GenerativeModel('gemini-pro-vision')
        image_part = {
            "mime_type": "image/jpeg", # Assuming JPEG, can be adjusted
            "data": base64.b64encode(image_bytes).decode()
        }
        prompt = "Describe this image. It is from a data science course forum and likely part of a student's question or instructor response about code, data, or errors. Be concise and clear. Just return the description and keep response concise. Don't cross 500 tokens."
        
        # To limit output tokens, we can use generation_config
        generation_config = genai.types.GenerationConfig(
            max_output_tokens=500 
        )
        
        response = model.generate_content([prompt, image_part], generation_config=generation_config)
        return response.text.strip()
    except Exception as e:
        print(f"  [!] Gemini Error: {e}")
        return "Could not generate image description."

# %% [markdown]
# ### Process Post Content

# %%
def process_post_content(html_content: str, session: requests.Session) -> str:
    """
    Parses HTML, finds images, replaces them with Gemini descriptions,
    and returns clean text.
    """
    soup = BeautifulSoup(html_content, "html.parser")

    # Find all images in the post
    for img in soup.find_all("img"):
        img_url = img.get("src")
        
        # Ensure it's a full URL
        if not img_url.startswith("http"):
            img_url = DISCOURSE_URL + img_url

        try:
            print(f"    -> Found image: {img_url}")
            img_response = session.get(img_url, timeout=10)
            img_response.raise_for_status()
            
            # Get description from Gemini
            description = get_image_description(img_response.content)
            print(f"    -> Description: {description[:80]}...") # Print a snippet
            
            # Replace the <img> tag with a descriptive text node
            description_text = f" [Image: {description}] "
            img.replace_with(description_text)

        except requests.exceptions.RequestException as e:
            print(f"  [!] Failed to download image {img_url}: {e}")
            img.replace_with(" [Image: Could not be downloaded] ")
        except Exception as e:
            print(f"  [!] An unexpected error occurred with image {img_url}: {e}")
            img.replace_with(" [Image: Processing error] ")

    return soup.get_text().strip()

# %%
all_posts = []
checkpoint_file = "checkpoint_posts_with_images.json"
start_topic_idx = 0
start_page = 1

# Note: You should have a try/except block here for loading the checkpoint
# For simplicity in this example, we start fresh.

try:
    for topic_idx in range(start_topic_idx, len(all_topics)):
        topic = all_topics[topic_idx]
        topic_id = topic["id"]
        slug = topic["slug"]
        # Use the full URL from your topics data if available
        topic_url = f"{DISCOURSE_URL}/t/{slug}/{topic_id}"
        page = start_page if topic_idx == start_topic_idx else 1

        print(f"Processing topic {topic_idx+1}/{len(all_topics)}: {topic['title']}")

        while True:
            current_url = f"{topic_url}.json?page={page}"
            print(f"  Fetching: {current_url} | Posts so far: {len(all_posts)}")
            resp = session.get(current_url)
            if resp.status_code != 200:
                print(f"    Error {resp.status_code}, skipping page {page} of topic {topic_id}")
                break
            
            topic_data = resp.json()
            posts = topic_data.get("post_stream", {}).get("posts", [])
            if not posts:
                break

            for post in posts:
                created_at = parse_dt(post["created_at"])
                if START_DATE <= created_at <= END_DATE:
                    post_number = post["post_number"]
                    post_url = f"{DISCOURSE_URL}/t/{slug}/{topic_id}/{post_number}"
                    
                    # *** KEY CHANGE HERE ***
                    # Use the new processing function instead of the simple html_to_text
                    print(f"  -> Processing post #{post_number}")
                    content = process_post_content(post["cooked"], session)
                    
                    all_posts.append({
                        "url": post_url,
                        "title": topic.get("title", "No Title"), # Add title for context
                        "text": content
                    })

            if len(posts) < 20:
                break
            page += 1
        
        # Reset page for the next topic
        start_page = 1
        # Consider checkpointing here after each topic

except Exception as e:
    print(f"\nAn exception occurred: {e}. Saving checkpoint.")
    # Add your checkpoint saving logic here
    raise

print(f"\nDone! Total posts collected: {len(all_posts)}")

# Save final output
with open("tds_discourse_posts_processed.json", "w") as f:
    json.dump(all_posts, f, indent=2)

# %%
# # Resume progress if checkpoint exists
# if os.path.exists(checkpoint_file):
#     with open(checkpoint_file, "r") as f:
#         data = json.load(f)
#         all_posts = data["all_posts"]
#         start_topic_idx = data["start_topic_idx"]
#         start_page = data["start_page"]
#     print(f"Resuming from topic #{start_topic_idx}, page {start_page}, {len(all_posts)} posts collected.")

try:
    for topic_idx in range(start_topic_idx, len(all_topics)):
        topic = all_topics[topic_idx]
        topic_id = topic["id"]
        slug = topic["slug"]
        topic_url = topic["url"]
        page = start_page if topic_idx == start_topic_idx else 1

        print(f"Processing topic {topic_idx+1}/{len(all_topics)}: {topic_url}")

        while True:
            current_url = f"{topic_url}.json?page={page}"
            print(f"  Fetching: {current_url} | Posts so far: {len(all_posts)}")
            resp = session.get(current_url)
            if resp.status_code != 200:
                print(f"    Error {resp.status_code}, skipping page {page} of topic {topic_id}")
                break

            topic_data = resp.json()
            posts = topic_data.get("post_stream", {}).get("posts", [])
            if not posts:
                break

            new_found = 0
            for post in posts:
                created_at = parse_dt(post["created_at"])
                if START_DATE <= created_at <= END_DATE:
                    post_number = post["post_number"]
                    post_url = f"{DISCOURSE_URL}/t/{slug}/{topic_id}/{post_number}"
                    content = html_to_text(post["cooked"])
                    all_posts.append({"url": post_url, "text": content})
                    new_found += 1
            if new_found == 0:
                # If no posts on this page matched, but there are posts, keep going
                # because valid posts might be on next page (or previous ones matched).
                # If this is not desired, remove this block.

                pass

            # Stop if less posts than a full page (no more pages)
            if len(posts) < 20:  # 20 is Discourse default posts per page
                break
            page += 1

            # Checkpoint every 5 pages
            if page % 5 == 0:
                with open(checkpoint_file, "w") as f:
                    json.dump({
                        "all_posts": all_posts,
                        "start_topic_idx": topic_idx,
                        "start_page": page
                    }, f)
                print(f"Checkpoint saved at topic {topic_idx}, page {page}")

        # After finishing this topic, reset start_page for next topic
        start_page = 1
        # Save checkpoint at each topic
        with open(checkpoint_file, "w") as f:
            json.dump({
                "all_posts": all_posts,
                "start_topic_idx": topic_idx+1,
                "start_page": 1
            }, f)
        print(f"Finished topic {topic_idx+1}. Posts so far: {len(all_posts)}")

except Exception as e:
    print("Exception occurred. Saving checkpoint...")
    with open(checkpoint_file, "w") as f:
        json.dump({
            "all_posts": all_posts,
            "start_topic_idx": topic_idx,
            "start_page": page
        }, f)
    print("Checkpoint saved.")
    raise

print(f"Done! Total posts collected: {len(all_posts)}")

# Save final output
with open("tds_discourse_posts.json", "w") as f:
    json.dump(all_posts, f, indent=2)
# Out:
# Processing topic 1/189: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=1 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=2 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=3 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=4 | Posts so far: 0
# Checkpoint saved at topic 0, page 5
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=5 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=6 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=7 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=8 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=9 | Posts so far: 0
# Checkpoint saved at topic 0, page 10
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=10 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=11 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=12 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=13 | Posts so far: 0
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=14 | Posts so far: 0
# Finished topic 1. Posts so far: 0
# Processing topic 2/189: https://discourse.onlinedegree.iitm.ac.in/t/tds-references-guidelines/67216
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/tds-references-guidelines/67216.json?page=1 | Posts so far: 0
# Finished topic 2. Posts so far: 0
# Processing topic 3/189: https://discourse.onlinedegree.iitm.ac.in/t/about-the-tools-in-data-science-category/23335
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/way-of-conduction-of-exam/163144.json?page=1 | Posts so far: 3324
# Finished topic 187. Posts so far: 3326
# Processing topic 188/189: https://discourse.onlinedegree.iitm.ac.in/t/tds-calendar-link-not-found/162425
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/tds-calendar-link-not-found/162425.json?page=1 | Posts so far: 3326
# Finished topic 188. Posts so far: 3328
# Processing topic 189/189: https://discourse.onlinedegree.iitm.ac.in/t/contribute-to-my-open-source-llm-classroom-assignment-evaluator/161214
#   Fetching: https://discourse.onlinedegree.iitm.ac.in/t/contribute-to-my-open-source-llm-classroom-assignment-evaluator/161214.json?page=1 | Posts so far: 3328
# Finished topic 189. Posts so far: 3333
# Done! Total posts collected: 3333

# %%
test = session.get('https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077.json?page=12')

# %%
test.json()
# Out:
# {'post_stream': {'posts': [{'id': 637821,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T11:32:33.598Z',
#     'cooked': '<p>Hi everyone! <img src="https://emoji.discourse-cdn.com/google/waving_hand.png?v=14" title=":waving_hand:" class="emoji" alt=":waving_hand:" loading="lazy" width="20" height="20"></p>\n<p>Here’s a quick overview of how the <strong>project evaluation</strong> process will work — both <strong>before</strong> and <strong>after</strong> the deadline:</p>\n<hr>\n<h3><a name="p-637821-before-the-deadline-self-evaluation-1" class="anchor" href="#p-637821-before-the-deadline-self-evaluation-1"></a><img src="https://emoji.discourse-cdn.com/google/white_check_mark.png?v=14" title=":white_check_mark:" class="emoji" alt=":white_check_mark:" loading="lazy" width="20" height="20"> <strong>Before the Deadline (Self-Evaluation)</strong></h3>\n<p>We’ve provided a <code>promptfoo.yml</code> file containing <strong>4 test cases</strong> to help you self-evaluate your API responses.</p>\n<ul>\n<li>You can run these tests <strong>locally</strong> to check how well your API is handling the inputs.</li>\n<li>You’re <strong>encouraged to add more test cases</strong> to the file and validate your logic thoroughly before submission.</li>\n</ul>\n<blockquote>\n<p><img src="https://emoji.discourse-cdn.com/google/pushpin.png?v=14" title=":pushpin:" class="emoji" alt=":pushpin:" loading="lazy" width="20" height="20"> These tests are for <strong>your own practice</strong> — they will not be used during final grading.</p>\n</blockquote>\n<hr>\n<h3><a name="p-637821-after-the-deadline-final-evaluation-2" class="anchor" href="#p-637821-after-the-deadline-final-evaluation-2"></a><img src="https://emoji.discourse-cdn.com/google/test_tube.png?v=14" title=":test_tube:" class="emoji" alt=":test_tube:" loading="lazy" width="20" height="20"> <strong>After the Deadline (Final Evaluation)</strong></h3>\n<p>Once submissions close, we will conduct an <strong>automated evaluation</strong> on your <strong>submitted API endpoint</strong> (not your local machine).</p>\n<ul>\n<li>We will test your deployed or exposed API using <strong>10 evaluation questions</strong>.</li>\n<li>The evaluation will be performed from our side — so make sure your API is <strong>accessible</strong>, <strong>reliable</strong>, and returns <strong>well-formatted</strong> responses.</li>\n</ul>\n<blockquote>\n<p><img src="https://emoji.discourse-cdn.com/google/warning.png?v=14" title=":warning:" class="emoji" alt=":warning:" loading="lazy" width="20" height="20"> You don’t need to run any evaluation scripts after submission — we will directly call your endpoint with the test prompts.</p>\n</blockquote>\n<hr>\n<h3><a name="p-637821-summary-3" class="anchor" href="#p-637821-summary-3"></a><img src="https://emoji.discourse-cdn.com/google/rocket.png?v=14" title=":rocket:" class="emoji" alt=":rocket:" loading="lazy" width="20" height="20"> Summary</h3>\n<div class="md-table">\n<table>\n<thead>\n<tr>\n<th>Phase</th>\n<th>What You Do</th>\n<th>Tool Used</th>\n</tr>\n</thead>\n<tbody>\n<tr>\n<td>Before deadline</td>\n<td>Self-test using and extending <code>promptfoo.yml</code></td>\n<td>Promptfoo (local)</td>\n</tr>\n<tr>\n<td>After deadline</td>\n<td>We test your API with 10 questions</td>\n<td>Promptfoo (our end)</td>\n</tr>\n</tbody>\n</table>\n</div><hr>\n<p>If you face any issues running the Promptfoo tests locally, or need help exposing your API for evaluation, feel free to post your questions here. We’re here to help!</p>',
#     'post_number': 227,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T11:32:33.598Z',
#     'reply_count': 0,
#     'reply_to_post_number': 218,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 89,
#     'readers_count': 88,
#     'score': 17.8,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'reply_to_user': {'id': 45953,
#      'username': '24f2005659',
#      'name': 'B.S.Sriharsan',
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2005659/{size}/124614_2.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/227',
#     'user_cakedate': '2023-01-25',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637827,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T11:42:25.437Z',
#     'cooked': '<p>Hi <a class="mention" href="/u/saumya1">@saumya1</a></p>\n<p>Use promptfoo.yml file provided for self evaluation.<br>\nAlso look at this post <a href="https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/225" class="inline-onebox">Project1 - Virtual TA - Discussion Thread [TDS May 2025] - #225</a></p>',
#     'post_number': 228,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T11:42:25.437Z',
#     'reply_count': 0,
#     'reply_to_post_number': 215,
#     'quote_count': 0,
#     'incoming_link_count': 1,
#     'reads': 85,
#     'readers_count': 84,
#     'score': 22.0,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'reply_to_user': {'id': 27858,
#      'username': 'saumya1',
#      'name': 'chauhan saumyakumar dilipkumar',
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/saumya1/{size}/67528_2.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/228',
#     'user_cakedate': '2023-01-25',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637828,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T11:46:58.367Z',
#     'cooked': '<p>Hi <a class="mention" href="/u/harsh_choudhary">@Harsh_Choudhary</a></p>\n<p>Whatever api endpoint you submit it must send response in correct format when we test your endpoint. It doesn’t matter where you host your server. We don’t know when we will be testing your endpoint.</p>\n<p>quoting "(If you use ngrok, ensure that it is running continuously until you get your results.)</p>\n<p>" from <a href="https://tds.s-anand.net/#/project-tds-virtual-ta?id=deploy-your-application" rel="noopener nofollow ugc">Project1 page</a></p>',
#     'post_number': 229,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T11:46:58.367Z',
#     'reply_count': 0,
#     'reply_to_post_number': 212,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 91,
#     'readers_count': 90,
#     'score': 18.2,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'link_counts': [{'url': 'https://tds.s-anand.net/#/project-tds-virtual-ta?id=deploy-your-application',
#       'internal': False,
#       'reflection': False,
#       'title': 'Tools in Data Science',
#       'clicks': 0}],
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'reply_to_user': {'id': 38579,
#      'username': 'Harsh_Choudhary',
#      'name': 'Harsh Choudhary',
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/harsh_choudhary/{size}/114548_2.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/229',
#     'user_cakedate': '2023-01-25',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637830,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T11:50:25.834Z',
#     'cooked': '<p>Hi <a class="mention" href="/u/24f1000922">@24f1000922</a> It will be base64</p>\n<hr>\n<p>Quoting <code>The endpoint must accept a POST request, e.g. POST https://app.example.com/api/ with a student question as well as optional base64 file attachments as JSON.</code> from <a href="https://tds.s-anand.net/#/project-tds-virtual-ta" rel="noopener nofollow ugc">Project 1 page </a></p>\n<p>Example :</p>\n<pre><code class="lang-auto">curl "https://app.example.com/api/" \\\n  -H "Content-Type: application/json" \\\n  -d "{\\"question\\": \\"Should I use gpt-4o-mini which AI proxy supports, or gpt3.5 turbo?\\", \\"image\\": \\"$(base64 -w0 project-tds-virtual-ta-q1.webp)\\"}"\n\n</code></pre>',
#     'post_number': 230,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T11:50:25.834Z',
#     'reply_count': 0,
#     'reply_to_post_number': 210,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 93,
#     'readers_count': 92,
#     'score': 18.6,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'link_counts': [{'url': 'https://tds.s-anand.net/#/project-tds-virtual-ta',
#       'internal': False,
#       'reflection': False,
#       'title': 'Tools in Data Science',
#       'clicks': 1}],
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'reply_to_user': {'id': 40596,
#      'username': '24f1000922',
#      'name': 'Adarsh',
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f1000922/{size}/120606_2.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/230',
#     'user_cakedate': '2023-01-25',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637831,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T11:51:45.816Z',
#     'cooked': '<p>Hi <a class="mention" href="/u/muthupalaniappan">@Muthupalaniappan</a></p>\n<p>You can use any model for embeddings and for chat completions.</p>',
#     'post_number': 231,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T11:51:45.816Z',
#     'reply_count': 0,
#     'reply_to_post_number': 206,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 87,
#     'readers_count': 86,
#     'score': 17.4,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'reply_to_user': {'id': 11218,
#      'username': 'Muthupalaniappan',
#      'name': 'Muthupalaniappan',
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/muthupalaniappan/{size}/18686_2.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/231',
#     'user_cakedate': '2023-01-25',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637851,
#     'name': 'Karvy Singh',
#     'username': 'Karvy',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/karvy/{size}/67600_2.png',
#     'created_at': '2025-06-11T12:53:45.980Z',
#     'cooked': '<p><a class="mention" href="/u/jivraj">@Jivraj</a> <a class="mention" href="/u/carlton">@carlton</a> <a class="mention" href="/u/hritikroshan_hrm">@HritikRoshan_HRM</a> sir,</p>\n<p>can you please specify how should be program our API to accept an image?<br>\nAs mentioned in the Project-1, should we program it assuming we will get a base64 str<br>\nOR we should assume it will be in form of an url?</p>\n<p>Since the only Question with image in promptfoo.yaml is right now is rejected, how can we test an image file please help with the same sir.</p>\n<p>Thanks &amp; Regards</p>',
#     'post_number': 233,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T12:53:45.980Z',
#     'reply_count': 1,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 83,
#     'readers_count': 82,
#     'score': 21.6,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Karvy Singh',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 31631,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/233',
#     'user_cakedate': '2024-06-04',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637855,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T12:59:30.888Z',
#     'cooked': '<p>Hi <a class="mention" href="/u/karvy">@Karvy</a></p>\n<aside class="quote group-ds-students" data-username="Karvy" data-post="233" data-topic="176077">\n<div class="title">\n<div class="quote-controls"></div>\n<img alt="" width="24" height="24" src="https://dub1.discourse-cdn.com/flex013/user_avatar/discourse.onlinedegree.iitm.ac.in/karvy/48/67600_2.png" class="avatar"> Karvy:</div>\n<blockquote>\n<p>Since the only Question with image in promptfoo.yaml is right now is rejected, how can we test an image file please help with the same sir.</p>\n</blockquote>\n</aside>\n<p>Keep image file in the same directory where your promptfu file is present.</p>\n<hr>\n<p>Additionally read this post.</p>\n<aside class="quote" data-post="230" data-topic="176077">\n  <div class="title">\n    <div class="quote-controls"></div>\n    <img alt="" width="24" height="24" src="https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/48.png" class="avatar">\n    <a href="https://discourse.onlinedegree.iitm.ac.in/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/230">Project1 - Virtual TA - Discussion Thread [TDS May 2025]</a> <a class="badge-category__wrapper " href="/c/courses/tds-kb/34"><span data-category-id="34" style="--category-badge-color: #0088CC; --category-badge-text-color: #FFFFFF; --parent-category-badge-color: #3AB54A;" data-parent-category-id="9" data-drop-close="true" class="badge-category --has-parent" title="This category is created to address subject-specific queries related to Tools in Data Science"><span class="badge-category__name">Tools in Data Science</span></span></a>\n  </div>\n  <blockquote>\n    Hi <a class="mention" href="/u/24f1000922">@24f1000922</a> It will be base64 \n\nQuoting The endpoint must accept a POST request, e.g. POST https://app.example.com/api/ with a student question as well as optional base64 file attachments as JSON. from <a href="https://tds.s-anand.net/#/project-tds-virtual-ta" rel="noopener nofollow ugc">Project 1 page </a> \nExample : \ncurl "https://app.example.com/api/" \\\n  -H "Content-Type: application/json" \\\n  -d "{\\"question\\": \\"Should I use gpt-4o-mini which AI proxy supports, or gpt3.5 turbo?\\", \\"image\\": \\"$(base64 -w0 project-tds-virtual-ta-q1.webp)\\"}"\n  </blockquote>\n</aside>\n\n<p>Kind regards</p>',
#     'post_number': 234,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T12:59:30.888Z',
#     'reply_count': 1,
#     'reply_to_post_number': 233,
#     'quote_count': 1,
#     'incoming_link_count': 0,
#     'reads': 86,
#     'readers_count': 85,
#     'score': 37.2,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'count': 1, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/234',
#     'user_cakedate': '2023-01-25',
#     'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 1}],
#     'current_user_reaction': None,
#     'reaction_users_count': 1,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637862,
#     'name': 'Karvy Singh',
#     'username': 'Karvy',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/karvy/{size}/67600_2.png',
#     'created_at': '2025-06-11T13:30:51.704Z',
#     'cooked': '<p>Thank for the response sir, and sorry for the redundant query.</p>\n<p>So while making our data URI, shall we assume the image will always be .webp ?<br>\nKindly confirm.</p>',
#     'post_number': 235,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T13:30:51.704Z',
#     'reply_count': 1,
#     'reply_to_post_number': 234,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 85,
#     'readers_count': 84,
#     'score': 37.0,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Karvy Singh',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'reply_to_user': {'id': 15651,
#      'username': 'Jivraj',
#      'name': 'Jivraj Singh Shekhawat',
#      'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'count': 1, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 31631,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/235',
#     'user_cakedate': '2024-06-04',
#     'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 1}],
#     'current_user_reaction': None,
#     'reaction_users_count': 1,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637867,
#     'name': 'Sharan kumar E',
#     'username': '24f3004935',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f3004935/{size}/122436_2.png',
#     'created_at': '2025-06-11T13:39:03.507Z',
#     'cooked': '<p>i am using  AI PROXY token from <a href="https://github.com/sanand0/aiproxy" class="inline-onebox" rel="noopener nofollow ugc">GitHub - sanand0/aiproxy: Authorizing proxy for LLMs</a> . Could you clarify my error with respect to ai-proxy ?</p>',
#     'post_number': 236,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T13:39:03.507Z',
#     'reply_count': 0,
#     'reply_to_post_number': 226,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 85,
#     'readers_count': 84,
#     'score': 17.0,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Sharan kumar E',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'link_counts': [{'url': 'https://github.com/sanand0/aiproxy',
#       'internal': False,
#       'reflection': False,
#       'title': 'GitHub - sanand0/aiproxy: Authorizing proxy for LLMs',
#       'clicks': 2}],
#     'read': False,
#     'user_title': None,
#     'reply_to_user': {'id': 15651,
#      'username': 'Jivraj',
#      'name': 'Jivraj Singh Shekhawat',
#      'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 42370,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/236',
#     'user_cakedate': '2025-01-10',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637869,
#     'name': 'Jivraj Singh Shekhawat',
#     'username': 'Jivraj',
#     'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png',
#     'created_at': '2025-06-11T13:55:47.445Z',
#     'cooked': '<p>Hi <a class="mention" href="/u/karvy">@Karvy</a></p>\n<p>Image can be any type of image that are on discourse.</p>\n<p>There is way to handle images for processing(resizing, etc) via identifying mime-type from file headers that come through post request.</p>\n<hr>\n<p>To identify the <strong>MIME type</strong> of the image sent in the request, you need to:</p>\n<h3><a name="p-637869-step-1-decode-the-base64-string-1" class="anchor" href="#p-637869-step-1-decode-the-base64-string-1"></a><img src="https://emoji.discourse-cdn.com/google/magnifying_glass_tilted_left.png?v=14" title=":magnifying_glass_tilted_left:" class="emoji" alt=":magnifying_glass_tilted_left:" loading="lazy" width="20" height="20"> Step 1: Decode the base64 string</h3>\n<p>The incoming <code>image</code> field in the request JSON is a <strong>base64-encoded image</strong>, like this:</p>\n<pre data-code-wrap="json"><code class="lang-json">"image": "data of base64..."\n</code></pre>\n<p>On the server side (e.g., in Python), you’ll first <strong>decode the base64 string</strong>.</p>\n<h3><a name="p-637869-step-2-inspect-the-raw-bytes-to-get-mime-type-2" class="anchor" href="#p-637869-step-2-inspect-the-raw-bytes-to-get-mime-type-2"></a><img src="https://emoji.discourse-cdn.com/google/magnifying_glass_tilted_left.png?v=14" title=":magnifying_glass_tilted_left:" class="emoji" alt=":magnifying_glass_tilted_left:" loading="lazy" width="20" height="20"> Step 2: Inspect the raw bytes to get MIME type</h3>\n<p>There are a few ways to do this depending on your server stack. Below is a method using <strong>Python</strong>:</p>\n<hr>\n<h3><a name="p-637869-python-code-example-for-fastapi-flask-django-etc-3" class="anchor" href="#p-637869-python-code-example-for-fastapi-flask-django-etc-3"></a><img src="https://emoji.discourse-cdn.com/google/white_check_mark.png?v=14" title=":white_check_mark:" class="emoji" alt=":white_check_mark:" loading="lazy" width="20" height="20"> Python Code Example (for FastAPI, Flask, Django etc.)</h3>\n<pre data-code-wrap="python"><code class="lang-python">import base64\nimport imghdr\nimport mimetypes\nfrom io import BytesIO\n\ndef get_image_mimetype(base64_string):\n    # Decode base64 string\n    image_data = base64.b64decode(base64_string)\n\n    # Option 1: imghdr (basic)\n    img_type = imghdr.what(None, h=image_data)  # e.g., \'jpeg\', \'png\', \'webp\'\n    mime_type = f\'image/{img_type}\' if img_type else \'application/octet-stream\'\n    \n    return mime_type\n</code></pre>\n<h3><a name="p-637869-example-output-4" class="anchor" href="#p-637869-example-output-4"></a><img src="https://emoji.discourse-cdn.com/google/pushpin.png?v=14" title=":pushpin:" class="emoji" alt=":pushpin:" loading="lazy" width="20" height="20"> Example Output</h3>\n<p>If the image is WebP, it will return:</p>\n<pre data-code-wrap="python"><code class="lang-python">image/webp\n</code></pre>\n<hr>',
#     'post_number': 237,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T13:55:47.445Z',
#     'reply_count': 1,
#     'reply_to_post_number': 235,
#     'quote_count': 0,
#     'incoming_link_count': 3,
#     'reads': 89,
#     'readers_count': 88,
#     'score': 52.8,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Jivraj Singh Shekhawat',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': 'Course TA',
#     'title_is_group': False,
#     'reply_to_user': {'id': 31631,
#      'username': 'Karvy',
#      'name': 'Karvy Singh',
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/karvy/{size}/67600_2.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'count': 1, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'group_moderator': True,
#     'user_id': 15651,
#     'hidden': False,
#     'trust_level': 2,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/237',
#     'user_cakedate': '2023-01-25',
#     'reactions': [{'id': 'heart', 'type': 'emoji', 'count': 1}],
#     'current_user_reaction': None,
#     'reaction_users_count': 1,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637872,
#     'name': 'Akshobh Verma',
#     'username': '23f2003651',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f2003651/{size}/67172_2.png',
#     'created_at': '2025-06-11T14:10:03.922Z',
#     'cooked': '<p>(post deleted by author)</p>',
#     'post_number': 238,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-12T06:47:00.654Z',
#     'reply_count': 0,
#     'reply_to_post_number': None,
#     'quote_count': 0,
#     'incoming_link_count': 3,
#     'reads': 84,
#     'readers_count': 83,
#     'score': 31.8,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Akshobh Verma',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 2,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 24803,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': True,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/238',
#     'user_cakedate': '2024-01-18',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637886,
#     'name': 'Adarsh',
#     'username': '24f1000922',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f1000922/{size}/120606_2.png',
#     'created_at': '2025-06-11T15:09:30.744Z',
#     'cooked': '<p>what do you mean by your-openai-api-url.<br>\n<code>OPENAI_API_BASE=https://your-openai-api-url/v1</code></p>\n<p>i am using it as:</p>\n<pre><code class="lang-auto">    llm_model = ChatOpenAI(\n        model="gpt-4o-mini",\n        openai_api_key=AIPIPE_TOKEN,\n        openai_api_base="https://aiproxy.sanand.workers.dev/openai/v1"\n    )\n</code></pre>',
#     'post_number': 239,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T15:11:59.029Z',
#     'reply_count': 0,
#     'reply_to_post_number': 225,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 82,
#     'readers_count': 81,
#     'score': 16.4,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Adarsh',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 2,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'reply_to_user': {'id': 15651,
#      'username': 'Jivraj',
#      'name': 'Jivraj Singh Shekhawat',
#      'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png'},
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 40596,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/239',
#     'user_cakedate': '2024-10-20',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637890,
#     'name': 'Vansh Bordia',
#     'username': 'vanshbordia',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/vanshbordia/{size}/70391_2.png',
#     'created_at': '2025-06-11T15:28:56.374Z',
#     'cooked': '<p>Hi any updates on this? Or can we just increase our timeframe to get more posts in</p>',
#     'post_number': 240,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T15:28:56.374Z',
#     'reply_count': 0,
#     'reply_to_post_number': 179,
#     'quote_count': 0,
#     'incoming_link_count': 1,
#     'reads': 79,
#     'readers_count': 78,
#     'score': 20.8,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'Vansh Bordia',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'reply_to_user': {'id': 16094,
#      'username': 'carlton',
#      'name': "Carlton D'Silva",
#      'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in

#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
#     'can_wiki': False,
#     'read': False,
#     'user_title': None,
#     'bookmarked': False,
#     'actions_summary': [{'id': 2, 'can_act': True},
#      {'id': 6, 'can_act': True},
#      {'id': 3, 'can_act': True},
#      {'id': 4, 'can_act': True},
#      {'id': 8, 'can_act': True},
#      {'id': 10, 'can_act': True},
#      {'id': 7, 'can_act': True}],
#     'moderator': False,
#     'admin': False,
#     'staff': False,
#     'user_id': 27858,
#     'hidden': False,
#     'trust_level': 1,
#     'deleted_at': None,
#     'user_deleted': False,
#     'edit_reason': None,
#     'can_view_edit_history': True,
#     'wiki': False,
#     'post_url': '/t/project1-virtual-ta-discussion-thread-tds-may-2025/176077/241',
#     'user_cakedate': '2024-02-20',
#     'reactions': [],
#     'current_user_reaction': None,
#     'reaction_users_count': 0,
#     'current_user_used_main_reaction': False,
#     'can_accept_answer': False,
#     'can_unaccept_answer': False,
#     'accepted_answer': False,
#     'topic_accepted_answer': None},
#    {'id': 637940,
#     'name': 'chauhan saumyakumar dilipkumar',
#     'username': 'saumya1',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/saumya1/{size}/67528_2.png',
#     'created_at': '2025-06-11T19:43:11.008Z',
#     'cooked': '<p><div class="lightbox-wrapper"><a class="lightbox" href="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/1/f/1f79c601a5dca697cc28921c71179b69b4322f7f.png" data-download-href="/uploads/short-url/4urHoTpxRsa4A2OhhujoIKUO5xZ.png?dl=1" title="image" rel="noopener nofollow ugc"><img src="https://europe1.discourse-cdn.com/flex013/uploads/iitm/original/3X/1/f/1f79c601a5dca697cc28921c71179b69b4322f7f.png" alt="image" data-base62-sha1="4urHoTpxRsa4A2OhhujoIKUO5xZ" width="690" height="417" data-dominant-color="2C2A2A"><div class="meta"><svg class="fa d-icon d-icon-far-image svg-icon" aria-hidden="true"><use href="#far-image"></use></svg><span class="filename">image</span><span class="informations">1201×727 64.2 KB</span><svg class="fa d-icon d-icon-discourse-expand svg-icon" aria-hidden="true"><use href="#discourse-expand"></use></svg></div></a></div><br>\nplease <a class="mention" href="/u/carlton">@carlton</a> and <a class="mention" href="/u/jivraj">@Jivraj</a> sir help me i am getting 1 test case fail of expected url but i am confused that i am doing mistake in code or scrapping is done wrong? how do i resolve it please guide me</p>',
#     'post_number': 242,
#     'post_type': 1,
#     'posts_count': 275,
#     'updated_at': '2025-06-11T19:43:11.008Z',
#     'reply_count': 1,
#     'reply_to_post_number': 241,
#     'quote_count': 0,
#     'incoming_link_count': 0,
#     'reads': 73,
#     'readers_count': 72,
#     'score': 19.6,
#     'yours': False,
#     'topic_id': 176077,
#     'topic_slug': 'project1-virtual-ta-discussion-thread-tds-may-2025',
#     'display_username': 'chauhan saumyakumar dilipkumar',
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_bg_color': '',
#     'flair_color': '',
#     'flair_group_id': 294,
#     'badges_granted': [],
#     'version': 1,
#     'can_edit': False,
#     'can_delete': False,
#     'can_recover': False,
#     'can_see_hidden_post': False,
# ...
#     'username': 'saumya1',
#     'name': 'chauhan saumyakumar dilipkumar',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/saumya1/{size}/67528_2.png',
#     'post_count': 10,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 9033,
#     'username': 'siddharthghosh',
#     'name': 'Siddharth',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/siddharthghosh/{size}/18449_2.png',
#     'post_count': 9,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 24803,
#     'username': '23f2003651',
#     'name': 'Akshobh Verma',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f2003651/{size}/67172_2.png',
#     'post_count': 9,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 40596,
#     'username': '24f1000922',
#     'name': 'Adarsh',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f1000922/{size}/120606_2.png',
#     'post_count': 8,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 15552,
#     'username': '23f1001065',
#     'name': 'Akash kumbhakar ',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f1001065/{size}/62698_2.png',
#     'post_count': 8,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 5168,
#     'username': 'Nomad',
#     'name': 'Ajit',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/nomad/{size}/345_2.png',
#     'post_count': 6,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 38579,
#     'username': 'Harsh_Choudhary',
#     'name': 'Harsh Choudhary',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/harsh_choudhary/{size}/114548_2.png',
#     'post_count': 6,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 29977,
#     'username': '24f1001758',
#     'name': 'Soha Farhana ',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f1001758/{size}/66883_2.png',
#     'post_count': 5,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 34288,
#     'username': 'VarunAgnihotri',
#     'name': 'Varun Agnihotri',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/varunagnihotri/{size}/103035_2.png',
#     'post_count': 5,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 22948,
#     'username': '23f2003584',
#     'name': 'Student ',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f2003584/{size}/78906_2.png',
#     'post_count': 4,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 21449,
#     'username': '23f2003824',
#     'name': 'Shrijan kumar ',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f2003824/{size}/68148_2.png',
#     'post_count': 4,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 31928,
#     'username': 'Sahil_singh',
#     'name': 'Sahil kumar',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/sahil_singh/{size}/110463_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 25373,
#     'username': '23f3003877',
#     'name': 'Aryan  chauhan',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f3003877/{size}/66809_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 11218,
#     'username': 'Muthupalaniappan',
#     'name': 'Muthupalaniappan',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/muthupalaniappan/{size}/18686_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 45953,
#     'username': '24f2005659',
#     'name': 'B.S.Sriharsan',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/24f2005659/{size}/124614_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 0},
#    {'id': 23392,
#     'username': '23f2004143',
#     'name': 'Hari Govind J ',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f2004143/{size}/132723_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1},
#    {'id': 25847,
#     'username': '23f2004115',
#     'name': 'Rohit Maurya ',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/23f2004115/{size}/110353_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 0},
#    {'id': 15790,
#     'username': '22f3000940',
#     'name': 'Ranadeep',
#     'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/22f3000940/{size}/120128_2.png',
#     'post_count': 3,
#     'primary_group_name': 'ds-students',
#     'flair_name': 'ds-students',
#     'flair_url': None,
#     'flair_color': '',
#     'flair_bg_color': '',
#     'flair_group_id': 294,
#     'trust_level': 1}],
#   'created_by': {'id': 15651,
#    'username': 'Jivraj',
#    'name': 'Jivraj Singh Shekhawat',
#    'avatar_template': 'https://avatars.discourse-cdn.com/v4/letter/j/b9bd4f/{size}.png'},
#   'last_poster': {'id': 24955,
#    'username': 'vanshbordia',
#    'name': 'Vansh Bordia',
#    'avatar_template': '/user_avatar/discourse.onlinedegree.iitm.ac.in/vanshbordia/{size}/70391_2.png'},
#   'links': [{'url': 'https://tds.s-anand.net/#/project-tds-virtual-ta',
#     'title': 'Tools in Data Science',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 170,
#     'user_id': 15651,
#     'domain': 'tds.s-anand.net',
#     'root_domain': 's-anand.net'},
#    {'url': 'https://drive.google.com/drive/folders/1A5YW71BRu3F2ReNllzFflyvGM3YbAj2K?usp=sharing',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 77,
#     'user_id': 17206,
#     'domain': 'drive.google.com',
#     'root_domain': 'google.com'},
#    {'url': 'https://tds.s-anand.net/project-tds-virtual-ta-promptfoo.yaml',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 58,
#     'user_id': 5168,
#     'domain': 'tds.s-anand.net',
#     'root_domain': 's-anand.net'},
#    {'url': 'https://github.com/23f3004008/TDS-Project1-Data',
#     'title': 'GitHub - 23f3004008/TDS-Project1-Data',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 46,
#     'user_id': 24955,
#     'domain': 'github.com',
#     'root_domain': 'github.com'},
#    {'url': 'https://drive.google.com/drive/folders/1KimuBkDrsc5VXi0fKcHVOP866EDg9Csj?usp=drive_link',
#     'title': 'Discourse - Google Drive',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 32,
#     'user_id': 38579,
#     'domain': 'drive.google.com',
#     'root_domain': 'google.com'},
#    {'url': 'https://www.promptfoo.dev/docs/configuration/expected-outputs/model-graded/llm-rubric/',
#     'title': 'LLM Rubric | promptfoo',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 24,
#     'user_id': 16094,
#     'domain': 'www.promptfoo.dev',
#     'root_domain': 'promptfoo.dev'},
#    {'url': 'https://aipipe.org/openai/v1/chat/completions',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 17,
#     'user_id': 25373,
#     'domain': 'aipipe.org',
#     'root_domain': 'aipipe.org'},
#    {'url': 'https://www.promptfoo.dev/docs/providers/',
#     'title': 'LLM Providers | promptfoo',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 16,
#     'user_id': 16094,
#     'domain': 'www.promptfoo.dev',
#     'root_domain': 'promptfoo.dev'},
#    {'url': 'https://exam.sanand.workers.dev/project-tds-virtual-ta-promptfoo.yaml',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 15,
#     'user_id': 9033,
#     'domain': 'exam.sanand.workers.dev',
#     'root_domain': 'sanand.workers.dev'},
#    {'url': 'https://discourse.onlinedegree.iitm.ac.in/t/ga5-question-8-clarification/155939',
#     'title': 'GA5 Question 8 Clarification',
#     'internal': True,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 15,
#     'user_id': 5168,
#     'domain': 'discourse.onlinedegree.iitm.ac.in',
#     'root_domain': 'iitm.ac.in'},
#    {'url': 'https://drive.google.com/file/d/1ZF4afK-TsFGSPoLN_Il883j1-99HrZg5/view',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 11,
#     'user_id': 24803,
#     'domain': 'drive.google.com',
#     'root_domain': 'google.com'},
#    {'url': 'https://aiproxy.sanand.workers.dev/openai/',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 6,
#     'user_id': 31631,
#     'domain': 'aiproxy.sanand.workers.dev',
#     'root_domain': 'sanand.workers.dev'},
#    {'url': 'https://github.com/promptfoo/promptfoo/blob/main/site/static/config-schema.json',
#     'title': 'promptfoo/site/static/config-schema.json at main · promptfoo/promptfoo · GitHub',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 6,
#     'user_id': 24955,
#     'domain': 'github.com',
#     'root_domain': 'github.com'},
#    {'url': 'https://tds-project-1-zp2e.onrender.com/',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 6,
#     'user_id': 25847,
#     'domain': 'tds-project-1-zp2e.onrender.com',
#     'root_domain': 'tds-project-1-zp2e.onrender.com'},
#    {'url': 'https://aipipe.org/',
#     'title': 'AI Pipe',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 5,
#     'user_id': 24955,
#     'domain': 'aipipe.org',
#     'root_domain': 'aipipe.org'},
#    {'url': 'https://www.promptfoo.dev/docs/getting-started/',
#     'title': 'Getting started | promptfoo',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 5,
#     'user_id': 15651,
#     'domain': 'www.promptfoo.dev',
#     'root_domain': 'promptfoo.dev'},
#    {'url': 'https://www.promptfoo.dev/validator/',
#     'title': 'Config Validator | promptfoo',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 4,
#     'user_id': 24955,
#     'domain': 'www.promptfoo.dev',
#     'root_domain': 'promptfoo.dev'},
#    {'url': 'https://api.openai.com/',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 4,
#     'user_id': 31631,
#     'domain': 'api.openai.com',
#     'root_domain': 'openai.com'},
#    {'url': 'https://api.openai.com/:',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 4,
#     'user_id': 31631,
#     'domain': 'api.openai.com',
#     'root_domain': 'openai.com'},
#    {'url': 'https://tds.s-anand.net/#/2025-01/',
#     'title': 'Tools in Data Science',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 4,
#     'user_id': 20160,
#     'domain': 'tds.s-anand.net',
#     'root_domain': 's-anand.net'},
#    {'url': 'https://tds.s-anand.net/#/docker',
#     'title': 'Tools in Data Science',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 4,
#     'user_id': 15651,
#     'domain': 'tds.s-anand.net',
#     'root_domain': 's-anand.net'},
#    {'url': 'https://tds.s-anand.net/#/project-tds-virtual-ta:~:text=TDS%20Discourse%20posts%20with%20content%20from%201%20Jan%202025%20%2D%2014%20Apr%202025.',
#     'title': 'Tools in Data Science',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 4,
#     'user_id': 34288,
#     'domain': 'tds.s-anand.net',
#     'root_domain': 's-anand.net'},
#    {'url': 'https://vercel.com/docs/limits',
#     'title': 'Limits',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 3,
#     'user_id': 24955,
#     'domain': 'vercel.com',
#     'root_domain': 'vercel.com'},
#    {'url': 'https://github.com/sanand0/aiproxy',
#     'title': 'GitHub - sanand0/aiproxy: Authorizing proxy for LLMs',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 2,
#     'user_id': 42370,
#     'domain': 'github.com',
#     'root_domain': 'github.com'},
#    {'url': 'https://render.com/docs/free',
#     'title': 'Deploy for Free – Render Docs',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 2,
#     'user_id': 24955,
#     'domain': 'render.com',
#     'root_domain': 'render.com'},
#    {'url': 'https://tds.s-anand.net/#/2025-01',
#     'title': 'Tools in Data Science',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 2,
#     'user_id': 31142,
#     'domain': 'tds.s-anand.net',
#     'root_domain': 's-anand.net'},
#    {'url': 'https://discourse.onlinedegree.iitm.ac.in/t/https-exam-sanand-workers-dev-project-tds-virtual-ta-promptfoo-yaml-is-not-opened/177666/2',
#     'title': 'Https://exam.sanand.workers.dev/project-tds-virtual-ta-promptfoo.yaml is not opened',
#     'internal': True,
#     'attachment': False,
#     'reflection': True,
#     'clicks': 1,
#     'user_id': 16094,
#     'domain': 'discourse.onlinedegree.iitm.ac.in',
#     'root_domain': 'iitm.ac.in'},
#    {'url': 'https://ai.google.dev/gemini-api/docs/rate-limits',
#     'title': 'Batas kapasitas \xa0|\xa0 Gemini API \xa0|\xa0 Google AI for Developers',
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 1,
#     'user_id': 24955,
#     'domain': 'ai.google.dev',
#     'root_domain': 'google.dev'},
#    {'url': 'https://aipipe.org/login:',
#     'title': None,
#     'internal': False,
#     'attachment': False,
#     'reflection': False,
#     'clicks': 1,
#     'user_id': 26197,
#     'domain': 'aipipe.org',
#     'root_domain': 'aipipe.org'}]},
#  'pending_posts': [],
#  'bookmarks': []}
